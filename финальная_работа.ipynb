# %% [markdown]
# # Финальная работа

# %%
# Импортируем необходимые библиотеки
import pandas as pd
import numpy as np
import warnings
import pickle
import dill
import re
from sklearn.decomposition import PCA
from imblearn.over_sampling import RandomOverSampler
from sklearn.dummy import DummyClassifier
from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as ImbPipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import (
                            train_test_split,
                            cross_val_score,
                            KFold)
from sklearn.ensemble import(
                     GradientBoostingClassifier,
                     RandomForestClassifier)
from sklearn.preprocessing import(
                             StandardScaler,
                             OneHotEncoder)
from sklearn.metrics import (
                            roc_auc_score,
                            classification_report)

# %%
# оформление — скрытие предупреждений
warnings.filterwarnings("ignore")

# константы
RS = 42 # RANDOM_STATE

# %%
# Функции
def get_info(data):
    '''
    Возвращает основную информацию о датасете
    '''
    print(f'Основные показатели датасета:')
    print('-'*40)
    print(f'Количество признаков: {data.shape[1]}')
    print('-'*40)
    print(f'Количество сэмплов: {data.shape[0]}')
    print('-'*40,end='\n\n')
    print(f'Количество дубликатов: {data.duplicated().sum()}')
    print('-'*40,end='\n\n')
    print('Пример данных:')
    display(data.head(3))


def calculate_missing_data(data):

    # Вывод основной информации о DataFrame
    data.info()

    # Расчет пропусков и процентов пропусков
    missing_data = data.isna().sum()
    missing_percent = (missing_data / len(data)) * 100
    missing_percent = missing_percent.round(2)

    missing_info = pd.DataFrame({
        'Пропуски': missing_data,
        'Процент пропусков': missing_percent
    })

    return missing_info


def check_missing_values(data):
    '''
    Проверка пропусков в признаках
    '''
    for column in data.columns:
        missing_values_count = data[column].isna().sum()
        print(f"Пропущенных значений в признаке {column}: {missing_values_count}")

# %% [markdown]
# ### Знакомство с данными

# %%
df1 = pd.read_csv('ga_sessions.csv', low_memory=False)

# %%
df = pd.read_csv('ga_hits.csv')

# %%
# Получаем основную информацию о датасете df1
get_info(df1)
# Out:
# Основные показатели датасета:
# ----------------------------------------
# Количество признаков: 18
# ----------------------------------------
# Количество сэмплов: 1860042
# ----------------------------------------
#
# Количество дубликатов: 0
# ----------------------------------------
#
# Пример данных:
#                                   session_id              client_id  \
# 0  9055434745589932991.1637753792.1637753792  2108382700.1637753791
# 1   905544597018549464.1636867290.1636867290   210838531.1636867288
# 2  9055446045651783499.1640648526.1640648526  2108385331.1640648523
#
#    visit_date visit_time  visit_number            utm_source utm_medium  \
# 0  2021-11-24   14:36:32             1  ZpYIoDJMcFzVoPFsHGJL     banner
# 1  2021-11-14   08:21:30             1  MvfHsxITijuriZxsqZqt        cpm
# 2  2021-12-28   02:42:06             1  ZpYIoDJMcFzVoPFsHGJL     banner
#
#            utm_campaign         utm_adcontent           utm_keyword  \
# 0  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp  puhZPIYqKXeFPaUviSjo
# 1  FTjNLDyTrXaWYgZymFkV  xhoenQgDQsgfEPYNPwKO  IGUCNvHlhfHpROGclCit
# 2  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp  puhZPIYqKXeFPaUviSjo
#
#   device_category device_os device_brand device_model  \
# 0          mobile   Android       Huawei          NaN
# 1          mobile   Android      Samsung          NaN
# 2          mobile   Android       Huawei          NaN
#
#   device_screen_resolution    device_browser geo_country     geo_city
# 0                  360x720            Chrome      Russia     Zlatoust
# 1                  385x854  Samsung Internet      Russia       Moscow
# 2                  360x720            Chrome      Russia  Krasnoyarsk

# %%
# Получаем основную информацию о датасете df
get_info(df)
# Out:
# Основные показатели датасета:
# ----------------------------------------
# Количество признаков: 11
# ----------------------------------------
# Количество сэмплов: 15726470
# ----------------------------------------
#
# Количество дубликатов: 0
# ----------------------------------------
#
# Пример данных:
#                                   session_id    hit_date  hit_time  \
# 0  5639623078712724064.1640254056.1640254056  2021-12-23  597864.0
# 1  7750352294969115059.1640271109.1640271109  2021-12-23  597331.0
# 2   885342191847998240.1640235807.1640235807  2021-12-23  796252.0
#
#    hit_number hit_type hit_referer  \
# 0          30    event         NaN
# 1          41    event         NaN
# 2          49    event         NaN
#
#                                        hit_page_path event_category  \
# 0  sberauto.com/cars?utm_source_initial=google&ut...           quiz
# 1  sberauto.com/cars/fiat?city=1&city=18&rental_c...           quiz
# 2  sberauto.com/cars/all/volkswagen/polo/e994838f...           quiz
#
#   event_action event_label  event_value
# 0    quiz_show         NaN          NaN
# 1    quiz_show         NaN          NaN
# 2    quiz_show         NaN          NaN

# %% [markdown]
# ## Оценка полноты и чистоты данных

# %%
calculate_missing_data(df1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1860042 entries, 0 to 1860041
# Data columns (total 18 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   session_id                object
#  1   client_id                 object
#  2   visit_date                object
#  3   visit_time                object
#  4   visit_number              int64
#  5   utm_source                object
#  6   utm_medium                object
#  7   utm_campaign              object
#  8   utm_adcontent             object
#  9   utm_keyword               object
#  10  device_category           object
#  11  device_os                 object
#  12  device_brand              object
#  13  device_model              object
#  14  device_screen_resolution  object
#  15  device_browser            object
#  16  geo_country               object
#  17  geo_city                  object
# dtypes: int64(1), object(17)
# memory usage: 255.4+ MB
#                           Пропуски  Процент пропусков
# session_id                       0               0.00
# client_id                        0               0.00
# visit_date                       0               0.00
# visit_time                       0               0.00
# visit_number                     0               0.00
# utm_source                      97               0.01
# utm_medium                       0               0.00
# utm_campaign                219603              11.81
# utm_adcontent               335615              18.04
# utm_keyword                1082061              58.17
# device_category                  0               0.00
# device_os                  1070138              57.53
# device_brand                367178              19.74
# device_model               1843704              99.12
# device_screen_resolution         0               0.00
# device_browser                   0               0.00
# geo_country                      0               0.00
# geo_city                         0               0.00

# %%
calculate_missing_data(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15726470 entries, 0 to 15726469
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   session_id      object
#  1   hit_date        object
#  2   hit_time        float64
#  3   hit_number      int64
#  4   hit_type        object
#  5   hit_referer     object
#  6   hit_page_path   object
#  7   event_category  object
#  8   event_action    object
#  9   event_label     object
#  10  event_value     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 1.3+ GB
#                 Пропуски  Процент пропусков
# session_id             0               0.00
# hit_date               0               0.00
# hit_time         9160322              58.25
# hit_number             0               0.00
# hit_type               0               0.00
# hit_referer      6274804              39.90
# hit_page_path          0               0.00
# event_category         0               0.00
# event_action           0               0.00
# event_label      3760184              23.91
# event_value     15726470             100.00

# %%
# Удаляем неинформативные признаки, а также признаки, где процент пропусков 99-100%
columns_for_drop = ['device_model', 'utm_keyword', 'device_screen_resolution', 'client_id', 
                    'utm_campaign', 'utm_adcontent', 'visit_date', 'visit_time']
df1 = df1.drop(columns=columns_for_drop) 
df1.head()
# Out:
#                                   session_id  visit_number  \
# 0  9055434745589932991.1637753792.1637753792             1
# 1   905544597018549464.1636867290.1636867290             1
# 2  9055446045651783499.1640648526.1640648526             1
# 3  9055447046360770272.1622255328.1622255328             1
# 4  9055447046360770272.1622255345.1622255345             2
#
#              utm_source utm_medium device_category device_os device_brand  \
# 0  ZpYIoDJMcFzVoPFsHGJL     banner          mobile   Android       Huawei
# 1  MvfHsxITijuriZxsqZqt        cpm          mobile   Android      Samsung
# 2  ZpYIoDJMcFzVoPFsHGJL     banner          mobile   Android       Huawei
# 3  kjsLglQLzykiRbcDiGcD        cpc          mobile       NaN       Xiaomi
# 4  kjsLglQLzykiRbcDiGcD        cpc          mobile       NaN       Xiaomi
#
#      device_browser geo_country     geo_city
# 0            Chrome      Russia     Zlatoust
# 1  Samsung Internet      Russia       Moscow
# 2            Chrome      Russia  Krasnoyarsk
# 3            Chrome      Russia       Moscow
# 4            Chrome      Russia       Moscow

# %%
columns_for_drop1 = ['event_value', 'hit_time', 'hit_referer', 'event_label']
df = df.drop(columns=columns_for_drop1) 
df.head()
# Out:
#                                   session_id    hit_date  hit_number hit_type  \
# 0  5639623078712724064.1640254056.1640254056  2021-12-23          30    event
# 1  7750352294969115059.1640271109.1640271109  2021-12-23          41    event
# 2   885342191847998240.1640235807.1640235807  2021-12-23          49    event
# 3   142526202120934167.1640211014.1640211014  2021-12-23          46    event
# 4  3450086108837475701.1640265078.1640265078  2021-12-23          79    event
#
#                                        hit_page_path event_category  \
# 0  sberauto.com/cars?utm_source_initial=google&ut...           quiz
# 1  sberauto.com/cars/fiat?city=1&city=18&rental_c...           quiz
# 2  sberauto.com/cars/all/volkswagen/polo/e994838f...           quiz
# 3  sberauto.com/cars?utm_source_initial=yandex&ut...           quiz
# 4  sberauto.com/cars/all/mercedes-benz/cla-klasse...           quiz
#
#   event_action
# 0    quiz_show
# 1    quiz_show
# 2    quiz_show
# 3    quiz_show
# 4    quiz_show

# %% [markdown]
# #  Разведочный анализ данных

# %%
# Выделяем марку автомобиля из признака
def extract_short_model(hit_page_path):
    '''
    Выделяет марку автомобиля из признака
    '''
    parts = hit_page_path.split('/')
    if len(parts) > 3:
        short_model = parts[3]
        # Удаляем параметры из строки и оставляем только буквенно-цифровые символы и дефисы
        short_model = re.split(r'[?&]', short_model)[0]
        # Проверяем, что строка состоит только из буквенно-цифровых символов и дефисов
        if re.match(r'^[a-zA-Z0-9\-]+$', short_model):
            return short_model
    return 'unknown'

# %%
# Создаём новую фичу
df['short_model'] = df['hit_page_path'].apply(extract_short_model)

# %%
# Определяем целевое действие
df.event_action = df.event_action.replace({'sub_car_claim_click' : 1, 'sub_car_claim_submit_click': 1,
'sub_open_dialog_click': 1, 'sub_custom_question_submit_click': 1,
'sub_call_number_click': 1, 'sub_callback_submit_click': 1, 'sub_submit_success': 1,
'sub_car_request_submit_click' : 1})

# %%
df.loc[(df.event_action != 1), 'event_action'] = 0 
df.event_action.value_counts(dropna=False)
# Out:
# event_action
# 0    15621562
# 1      104908
# Name: count, dtype: int64

# %%
# удаляем неинформативные признаки, а также фичи, которые могут считаться утечкой
columns_for_drop2 = ['hit_date', 'hit_number', 'hit_type', 'hit_page_path']
df = df.drop(columns=columns_for_drop2) 
df.head()
# Out:
#                                   session_id event_category event_action  \
# 0  5639623078712724064.1640254056.1640254056           quiz            0
# 1  7750352294969115059.1640271109.1640271109           quiz            0
# 2   885342191847998240.1640235807.1640235807           quiz            0
# 3   142526202120934167.1640211014.1640211014           quiz            0
# 4  3450086108837475701.1640265078.1640265078           quiz            0
#
#      short_model
# 0        unknown
# 1        unknown
# 2     volkswagen
# 3        unknown
# 4  mercedes-benz

# %% [markdown]
# #### Обьединение двух датафреймов

# %% [markdown]
# ##### Проверяем наличие дубликатов в признаке, по которому будем объединять датафреймы

# %%
print(df1['session_id'].duplicated().sum())
# Out:
# 0

# %%
print(df['session_id'].duplicated().sum())
# Out:
# 13991860

# %%
# Удаляем дубликаты перед объединением
df = df.drop_duplicates(subset=['session_id'])

# %%
print(df['session_id'].duplicated().sum())
# Out:
# 0

# %%
data = pd.merge(left=df1, right=df, on='session_id', how='inner')
get_info(data)
# Out:
# Основные показатели датасета:
# ----------------------------------------
# Количество признаков: 13
# ----------------------------------------
# Количество сэмплов: 1732266
# ----------------------------------------
#
# Количество дубликатов: 0
# ----------------------------------------
#
# Пример данных:
#                                   session_id  visit_number  \
# 0  9055434745589932991.1637753792.1637753792             1
# 1   905544597018549464.1636867290.1636867290             1
# 2  9055446045651783499.1640648526.1640648526             1
#
#              utm_source utm_medium device_category device_os device_brand  \
# 0  ZpYIoDJMcFzVoPFsHGJL     banner          mobile   Android       Huawei
# 1  MvfHsxITijuriZxsqZqt        cpm          mobile   Android      Samsung
# 2  ZpYIoDJMcFzVoPFsHGJL     banner          mobile   Android       Huawei
#
#      device_browser geo_country     geo_city event_category event_action  \
# 0            Chrome      Russia     Zlatoust  sub_page_view            0
# 1  Samsung Internet      Russia       Moscow  sub_page_view            0
# 2            Chrome      Russia  Krasnoyarsk    search_form            0
#
#   short_model
# 0     unknown
# 1     unknown
# 2     unknown

# %% [markdown]
# #### Исследуем целевой признак

# %%
# Удаление пропусков в целевом признаке
data.dropna(subset='event_action', axis=0, inplace=True)

#проверяем баланс значений в признаке
print(data['event_action'].value_counts())
print('\nКоличество пропусков в признаке', data['event_action'].isna().sum())
count_1 = data['event_action'].sum()
count_0 = len(data) - count_1
percent_1 = (count_1 / len(data)) * 100
percent_0 = (count_0 / len(data)) * 100
print(f'\nПроцент значений 1: {percent_1:.2f}%\nПроцент значений 0: {percent_0:.2f}%')

# Исправление типа данных
data['event_action'] = data['event_action'].astype('int64')
# Out:
# event_action
# 0    1727037
# 1       5229
# Name: count, dtype: int64
#
# Количество пропусков в признаке 0
#
# Процент значений 1: 0.30%
# Процент значений 0: 99.70%

# %% [markdown]
# #### Вывод: в целевом признаке имеется сильный дисбаланс классов

# %% [markdown]
# ### Корреляционный анализ

# %%
# Изучим корреляцию между числовыми признаками
data['event_action'].corr(data['visit_number'])
# Out:
# 0.03173104530039895

# %%
# Частотный анализ для категориальных данных
for column in data.select_dtypes(include='object').columns:
    print(f"\nРаспределение значений в признаке '{column}':")
    print(data[column].value_counts())
# Out:
# Распределение значений в признаке 'session_id':
# session_id
# 9055434745589932991.1637753792.1637753792    1
# 629529258169981545.1626332167.1626332167     1
# 6295352713792576176.1634065074.1634065074    1
# 6295350622136026841.1626588901.1626588901    1
# 6295349887709233242.1639202906.1639202906    1
#                                             ..
# 3524000133754500026.1625142208.1625142208    1
# 3523993785803856201.1636161866.1636161866    1
# 352398731068897298.1621686290.1621686290     1
# 3523985479341028705.1640084833.1640084833    1
# 9055430416266113553.1640968742.1640968742    1
# Name: count, Length: 1732266, dtype: int64
#
# Распределение значений в признаке 'utm_source':
# utm_source
# ZpYIoDJMcFzVoPFsHGJL    552555
# fDLlAcSmythWSCVMvqvL    277060
# kjsLglQLzykiRbcDiGcD    245178
# MvfHsxITijuriZxsqZqt    175831
# BHcvLfOaCWvWTykYqHVe    110963
#                          ...
# DWvtKQncdpXXfLBjBmGj         1
# ZsHOHNXkbhgIDlKNiFMf         1
# hYVrCkhCPSqKBhZYhWVq         1
# OboZzsWwJIeGPLeiLGMq         1
# sbJRYgVfvcnqKJNDDYIr         1
# Name: count, Length: 280, dtype: int64
#
# Распределение значений в признаке 'utm_medium':
# utm_medium
# banner               525206
# cpc                  399395
# (none)               277060
# cpm                  229791
# referral             136851
# organic               55009
# email                 28287
# push                  27710
# stories               10472
# cpv                    7815
# blogger_channel        7731
# smartbanner            6501
# blogger_stories        4226
# tg                     3920
# cpa                    3266
# post                   2227
# outlook                1269
# app                    1211
# smm                    1194
# clicks                  908
# blogger_header          760
# (not set)               405
# info_text               335
# sms                     194
# landing                 127
# partner                  95
# link                     52
# cbaafe                   43
# CPM                      36
# yandex_cpc               31
# vk_smm                   25
# static                   17
# google_cpc               15
# article                  15
# web_polka                11
# fb_smm                    8
# medium                    8
# ok_smm                    6
# nkp                       5
# social                    5
# catalogue                 4
# main_polka                3
# linktest                  2
# users_msk                 2
# reach                     2
# promo_sber                2
# last                      1
# qrcodevideo               1
# qr                        1
# dom_click                 1
# promo_sbol                1
# tablet                    1
# landing_interests         1
# Sbol_catalog              1
# sber_app                  1
# Name: count, dtype: int64
#
# Распределение значений в признаке 'device_category':
# device_category
# mobile     1368679
# desktop     346891
# tablet       16696
# Name: count, dtype: int64
#
# Распределение значений в признаке 'device_os':
# device_os
# Android          425520
# iOS              182597
# Windows           81740
# Macintosh         23415
# Linux              4616
# (not set)           309
# Chrome OS            65
# BlackBerry           24
# Tizen                 7
# Firefox OS            3
# Nokia                 2
# Samsung               2
# Windows Phone         2
# Name: count, dtype: int64
#
# Распределение значений в признаке 'device_brand':
# device_brand
# Apple        503533
# Samsung      311641
# Xiaomi       269251
# Huawei       173828
# Realme        17926
#               ...
# Smarteo           1
# Star              1
# Mobiistar         1
# Fero              1
# Maxvi             1
# Name: count, Length: 200, dtype: int64
#
# Распределение значений в признаке 'device_browser':
# device_browser
# Chrome                              951573
# Safari                              436705
# YaBrowser                           123765
# Safari (in-app)                      65952
# Android Webview                      51919
# Samsung Internet                     44273
# Opera                                25094
# Firefox                              15738
# Edge                                 15196
# UC Browser                             815
# Mozilla Compatible Agent               336
# Android Runtime                        241
# [FBAN                                  115
# Instagram 208.0.0.32.135 Android        72
# MRCHROME                                72
# Instagram 209.0.0.21.119 Android        49
# Android Browser                         47
# Puffin                                  43
# Maxthon                                 30
# Internet Explorer                       24
# Opera Mini                              23
# Android                                 19
# Instagram 202.0.0.23.119                17
# Mozilla                                 16
# Instagram 194.0.0.36.172 Android        14
# Instagram 202.0.0.37.123 Android        12
# (not set)                               11
# com.vk.vkclient                          8
# Instagram 212.0.0.38.119 Android         6
# Coc Coc                                  6
# helloworld                               6
# Instagram 203.0.0.26.117                 6
# Instagram 192.0.0.37.119                 6
# Amazon Silk                              6
# Instagram 201.0.0.23.111                 5
# Instagram 216.0.0.12.135                 4
# Instagram 213.0.0.29.120 Android         4
# Instagram 207.0.0.28.118                 4
# Instagram 216.1.0.21.137 Android         4
# SeaMonkey                                3
# Instagram 213.0.0.19.117                 3
# Instagram 192.0.0.35.123 Android         3
# Instagram 158.0.0.30.123 Android         3
# MyApp                                    2
# Iron                                     2
# Instagram 199.0.0.27.120                 2
# Instagram 208.0.0.26.131                 2
# Instagram 199.1.0.34.119 Android         2
# NetFront                                 2
# MT6735_TD                                1
# NokiaX2-02                               1
# Nokia501                                 1
# com.zhiliaoapp.musically                 1
# Konqueror                                1
# Threads 202.0.0.23.119                   1
# Name: count, dtype: int64
#
# Распределение значений в признаке 'geo_country':
# geo_country
# Russia                 1682423
# Ukraine                   8455
# United States             8141
# Belarus                   3432
# Kazakhstan                2109
#                         ...
# Paraguay                     1
# New Caledonia                1
# Puerto Rico                  1
# Yemen                        1
# Congo - Brazzaville          1
# Name: count, Length: 159, dtype: int64
#
# Распределение значений в признаке 'geo_city':
# geo_city
# Moscow              750928
# Saint Petersburg    278402
# (not set)            73297
# Yekaterinburg        33555
# Krasnodar            30260
#                      ...
# Oldbury                  1
# Bad Breisig              1
# Ilza                     1
# Svishtov                 1
# Compiegne                1
# Name: count, Length: 2389, dtype: int64
#
# Распределение значений в признаке 'event_category':
# event_category
# sub_page_view                    862689
# card_web                         434592
# sub_button_click                 143271
# search_form                      100578
# listing_ads                       54763
# quiz                              49978
# cars                              31876
# auth                               9266
# greenday_sub_button_click          8689
# jivosite                           5723
# sap_search_form                    5153
# offers                             4949
# chat                               4378
# footer                             4242
# ad_banner                          3528
# sap_search__form                   2353
# navigation                         1421
# main_banners                        802
# sub_submit                          784
# profile_menu                        686
# scrolling_main_page                 683
# active_invitation                   590
# my_idea                             402
# header                              278
# greenday_listing_ads                196
# greenday_gtm.triggergroup            96
# add_ad                               76
# category_tile                        66
# main_services                        51
# phone                                46
# credit_landing_pos                   25
# greenday_sub_submit                  25
# main_advantages                       6
# tesla                                 1
# add_ad_city                           1
# add_ad_photo                          1
# add_ad_additional_information         1
# add_ad_vin                            1
# Name: count, dtype: int64
#
# Распределение значений в признаке 'short_model':
# short_model
# unknown                                                 1510187
# skoda                                                     49020
# mercedes-benz                                             31907
# lada-vaz                                                  27188
# volkswagen                                                24457
#                                                          ...
# phw                                                           1
# icql1                                                         1
# wish                                                          1
# qfs9swh3d                                                     1
# aldt4oxrsewjvejmpolarxaamnhrndgiz9eh27qoyhyyc7w0hryv          1
# Name: count, Length: 311, dtype: int64

# %% [markdown]
# #### Проверка пропусков после обьединения

# %%
check_missing_values(data)
# Out:
# Пропущенных значений в признаке session_id: 0
# Пропущенных значений в признаке visit_number: 0
# Пропущенных значений в признаке utm_source: 76
# Пропущенных значений в признаке utm_medium: 0
# Пропущенных значений в признаке device_category: 0
# Пропущенных значений в признаке device_os: 1013964
# Пропущенных значений в признаке device_brand: 347196
# Пропущенных значений в признаке device_browser: 0
# Пропущенных значений в признаке geo_country: 0
# Пропущенных значений в признаке geo_city: 0
# Пропущенных значений в признаке event_category: 0
# Пропущенных значений в признаке event_action: 0
# Пропущенных значений в признаке short_model: 0

# %%
# Удаление строк с пропущенными значениями в указанных столбцах
data.dropna(subset=['device_os', 'device_brand', 'utm_source'], inplace=True)

# %%
data.device_os.unique()
# Out:
# array(['Android', 'iOS', '(not set)', 'BlackBerry', 'Tizen', 'Firefox OS',
#        'Nokia', 'Samsung', 'Windows Phone'], dtype=object)

# %%
data.device_brand.unique()
# Out:
# array(['Huawei', 'Samsung', 'Lenovo', 'Apple', 'Xiaomi', 'Meizu',
#        'OnePlus', 'Realme', 'OPPO', '(not set)', 'Philips', 'Vivo',
#        'Nokia', 'Alcatel', 'LG', 'BQ', 'Tecno', 'Asus', 'itel', 'Infinix',
#        'ZTE', 'Wiko', 'Google', 'Sony', 'Blackview', 'Cubot', 'DOOGEE',
#        'DEXP', 'Motorola', 'TP-Link', 'Hisense', 'Acer', 'Oukitel',
#        'LeEco', 'Prestigio', 'POCO', 'Vsmart', 'HTC', 'Ulefone', 'CAT',
#        'Leagoo', 'InFocus', 'Inoi', 'BlackBerry', 'Micromax', 'Umidigi',
#        'Jiake', 'ZOJI', 'Mozilla', 'Neffos', 'Highscreen', 'Karbonn',
#        'TCL', 'BLU', 'Haier', 'Vertex', 'Coolpad', 'HOMTOM', 'LeTV', 'A1',
#        'Sharp', 'General Mobile', 'Gome', 'Egreat', 'Mito', 'Wileyfox',
#        'SenseIT', 'Archos', 'Keecoo', 'Vernee', 'Panasonic', 'InnJoo',
#        'Iris', 'Black Fox', 'Lava', 'myPhone', 'AGM', 'Nuu', 'UGOOS',
#        'Alldocube', 'MTC', 'Symphony', 'Wigor', 'Oysters', 'Komu', 'Fly',
#        'Gionee', 'Artel', 'Ananda', 'Smartisan', 'Elephone', 'Kingplay',
#        'Chuwi', 'Flexymove', 'Advan', 'Amazon', 'Fairphone', 'Teclast',
#        'Corn', 'TurboPad', 'China Mobile', 'MXQ', 'Kyocera', 'teXet',
#        'Poptel', 'INUI', 'Hafury', 'Krip', 'Digma', 'Digiland',
#        'SonyEricsson', 'Unihertz', 'Geotel', 'BLUBOO', 'Kata', 'Vertu',
#        'Nomu', 'Ken Xin Da', 'iNew', 'Irbis', 'Pantech', 'Dark',
#        'QMobile', 'Gretel', 'Celkon', 'Essential', 'Tesla', 'NOA',
#        'Vodafone', 'Explay', 'Billion', 'Evercoss', 'E&L', 'MediaTek',
#        'Ark', 'Wexler', 'Smarteo', 'Mobiistar', 'ThL', 'Honor', 'Xgody',
#        'Yuntab', 'Tele2', 'Evertek', 'Verizon', 'Wieppo', 'Qbex',
#        'Gigaset', 'Dell', 'Olla', 'UMI', 'Yota Devices', 'Kenxinda',
#        'Vestel', 'MLS', 'Dynamic', 'FREETEL', 'Caterpillar', 'Guophone'],
#       dtype=object)

# %%
data.utm_medium.unique()
# Out:
# array(['banner', 'cpm', 'cpc', 'referral', '(none)', 'organic', 'smm',
#        'blogger_channel', 'app', 'push', 'partner', 'cpa', 'email',
#        'smartbanner', 'info_text', 'clicks', 'landing', 'blogger_stories',
#        'post', 'tg', '(not set)', 'google_cpc', 'outlook',
#        'blogger_header', 'vk_smm', 'cpv', 'fb_smm', 'sms',
#        'landing_interests', 'yandex_cpc', 'static', 'nkp', 'main_polka',
#        'ok_smm', 'stories', 'users_msk'], dtype=object)

# %%
# Подсчет количества строк, содержащих "none", "(not set), "unknown""
print("Количество строк, содержащих 'none', '(not set)', 'unknown':")
print((data == '(none)').sum())
print((data == '(not set)').sum())
print((data == 'unknown').sum())
# Out:
# Количество строк, содержащих 'none', '(not set)', 'unknown':
# session_id             0
# visit_number           0
# utm_source             0
# utm_medium         41753
# device_category        0
# device_os              0
# device_brand           0
# device_browser         0
# geo_country            0
# geo_city               0
# event_category         0
# event_action           0
# short_model            0
# dtype: int64
# session_id             0
# visit_number           0
# utm_source             0
# utm_medium           100
# device_category        0
# device_os              7
# device_brand        9018
# device_browser         0
# geo_country          196
# geo_city           17911
# event_category         0
# event_action           0
# short_model            0
# dtype: int64
# session_id              0
# visit_number            0
# utm_source              0
# utm_medium              0
# device_category         0
# device_os               0
# device_brand            0
# device_browser          0
# geo_country             0
# geo_city                0
# event_category          0
# event_action            0
# short_model        478213
# dtype: int64

# %%
# Удаление строк, содержащих "(none)", "(not set)", "unknown" в любом признаке
data = data[~data.apply(lambda row: row.astype(str).str.contains('none|not set|unknown').any(), axis=1)]

# %%
print((data == '(none)').sum())
print((data == '(not set)').sum())
print((data == 'unknown').sum())
# Out:
# session_id         0
# visit_number       0
# utm_source         0
# utm_medium         0
# device_category    0
# device_os          0
# device_brand       0
# device_browser     0
# geo_country        0
# geo_city           0
# event_category     0
# event_action       0
# short_model        0
# dtype: int64
# session_id         0
# visit_number       0
# utm_source         0
# utm_medium         0
# device_category    0
# device_os          0
# device_brand       0
# device_browser     0
# geo_country        0
# geo_city           0
# event_category     0
# event_action       0
# short_model        0
# dtype: int64
# session_id         0
# visit_number       0
# utm_source         0
# utm_medium         0
# device_category    0
# device_os          0
# device_brand       0
# device_browser     0
# geo_country        0
# geo_city           0
# event_category     0
# event_action       0
# short_model        0
# dtype: int64

# %%
unique_values = data['device_browser'].unique()
for value in unique_values:
    print(value)
# Out:
# YaBrowser
# Android Webview
# Chrome
# Safari
# Samsung Internet
# Safari (in-app)
# Opera
# Android Runtime
# UC Browser
# Puffin
# Instagram 216.0.0.12.135
# Amazon Silk
# Android Browser
# Firefox
# NokiaX2-02
# Nokia501

# %%
# Заменяем содержимое на 'Instagram', если строка содержит это слово
data['device_browser'] = data['device_browser'].apply(lambda x: 'Instagram' if 'Instagram' in x else x)

# %%
print(data['device_browser'].unique())
# Out:
# ['YaBrowser' 'Android Webview' 'Chrome' 'Safari' 'Samsung Internet'
#  'Safari (in-app)' 'Opera' 'Android Runtime' 'UC Browser' 'Puffin'
#  'Instagram' 'Amazon Silk' 'Android Browser' 'Firefox' 'NokiaX2-02'
#  'Nokia501']

# %%
data.short_model.unique()
# Out:
# array(['skoda', 'mercedes-benz', 'haval', 'kia', 'volkswagen', 'volvo',
#        'land-rover', 'renault', 'lada-vaz', 'nissan', 'toyota', 'bmw',
#        'lexus', 'honda', 'audi', 'porsche', 'mini', 'pajero', 'x3',
#        'peugeot', 'sportage', 'granta',
#        '3emjrhglwbrbpw76upwd8txntyo1c6ngmv8j7vrqv5ci8ifmtyyausuownlp2upx4mttf7pjgk',
#        'hyundai', 'camry', '5-serii', 'rio', 'sorento',
#        'lbgkrbejhmv1pokzbxgdge84n', 'outlander',
#        'kty9xbrney93n5i9esj3isfhtoau6z641tekgcbj6jy', 'rav-4', 'solaris',
#        'wish', 'c-klasse', 'a6', '6', 'atlas', 'o', '308', 'e-klasse',
#        'land-cruiser', 'creta', 'a6-allroad', 'corolla', 'priora',
#        '2121-4x4', 'lifan', 'chery', 'x5', 'duster', '1111-oka',
#        'iir8kfq9avye24oisc', 'geely', 'mazda', 'alphard', 'seltos', '3',
#        'hswjwjo63jfn5id8ul613dxtsbebclg12oladbybkqsm8h', 'almera',
#        'cruze', 'cx-5', 'note', 'chevrolet', 'h-1', 'i40', '100',
#        'lacetti', 'fortuner', 'land-cruiser-prado',
#        '6l6jwrd5klmwzuzngras5ky5dtxrumay55gks5lkdnosygr3zszzhx2ocuvsuzfyu8xgoqep',
#        'cerato', 'pathfinder', 'k5', 'cayenne', 'meriva', 'a5', 'sonata',
#        'jolion', 'logan', 'tucson', 'subaru', 'range-rover', 'captur',
#        'maxima', 'x-trail', 'accent', 'vesta',
#        'zpvhnyq60mzxtmrj8iuc2xvpcayiwr1g8qje50rwnduikax1ca0bjdzv2ikhzegje7dk4c4vd9ayn1qukquesf3duz5hbr',
#        'gls-klasse', 'murano', 'xc90', 'qashqai', 'nx', 'pajero-sport',
#        'polo',
#        'vwmqu9grswn6w093zzhdklfwupmojgec95qfdijmptkmuvjvzj1zoiiyuaieisuatsiwew4k2',
#        'prius', 'x7', 'x6', 'equus', 'tiovc', 'gla-klasse-amg',
#        'vh7s90lkdjaxwdkfxr4uwqgkfzp1yzqzguau9', 'e-klasse-amg', 'xray',
#        'gt-r', '2115', 'auris',
#        't9sb0itojuyhtqj44muahsqqj7p1fnqlrixcmowpv', '3-serii', 'lancer',
#        '6vri5tnww6ihkyrprzbgg', 'acura', 'santa-fe', 'gs',
#        '7sp7vzzihv3jfpugzp4oo', 'karoq', 'ford', 'cars', 'infiniti',
#        'b1zj0mjuhozfw', 'mitsubishi', '3qvkbd7pkjuejqd06kyufdthi5rau3hkd',
#        '4-serii', 'opel', 'daewoo', 'grand-vitara', 'fnuph', 'i3',
#        'jaguar', 'octavia', '62',
#        'mormvzuzm7mrsmalumfcgtyrebf8przgwcpvpospv8z420lfjrpri2cihjeyjsjebygunyhvg4ctn25gdbb1t4xrpspi',
#        'hilux', 'partner', 'niva', 'kalina',
#        'k4acgaxzpzct9zsky2458iqmhgod1lubslpi0blnjlltlbmuu7pkvakumqvihwpwqu38jtcdf0wu97xspo',
#        'ravon', 'estima',
#        'gew6uzqttyrftg0hbdtiv68nsnk62mapiad2omoliq85qo', 'challenger',
#        'carnival', '9vnptsnf4qc2afwgeb', 'uaz', 'm8', 'superb', 'largus',
#        'nexia', 'teana', 'amarok',
#        '93c1wqrverze2cryhgrxtk4t4grkcx1ktd9qfnugld', 'm', 'rx',
#        'insignia', 'terrano', 'elantra', 'cr-v', 'traveller',
#        '3fgq5lcimrojersgiztxmjk7ipfasspj',
#        '38qa7prgewcpvkkq6f0roixpbtsfdwrmrez5x8za', 'carina', 'malibu',
#        'arkana', 'q7', 'sxnsdllakzwflfq9w1ip46wxorjk1cpa', 'patrol',
#        'scirocco', 'juke', 'passat', 'asx', 'mondeo', 'corolla-spacio',
#        'grand-cherokee', 'gpzm4xpikngpc4rhavhigi', 'lx'], dtype=object)

# %%
# Список разрешенных значений (читабельных марок и моделей автомобилей)
allowed_models = [
    'skoda', 'mercedes-benz', 'haval', 'kia', 'volkswagen', 'volvo',
    'land-rover', 'renault', 'lada-vaz', 'nissan', 'toyota', 'bmw',
    'lexus', 'honda', 'audi', 'porsche', 'mini', 'pajero', 'x3',
    'peugeot', 'sportage', 'granta', 'hyundai', 'camry', '5-serii', 'rio',
    'sorento', 'outlander', 'rav-4', 'solaris', 'wish', 'c-klasse', 'a6',
    '6', 'atlas', '308', 'e-klasse', 'land-cruiser', 'creta', 'a6-allroad',
    'corolla', 'priora', '2121-4x4', 'lifan', 'chery', 'x5', 'duster',
    '1111-oka', 'geely', 'mazda', 'alphard', 'seltos', '3', 'almera',
    'cruze', 'cx-5', 'note', 'chevrolet', 'h-1', 'i40', '100', 'lacetti',
    'fortuner', 'land-cruiser-prado', 'cerato', 'pathfinder', 'k5',
    'cayenne', 'meriva', 'a5', 'sonata', 'jolion', 'logan', 'tucson',
    'subaru', 'range-rover', 'captur', 'maxima', 'x-trail', 'accent',
    'vesta', 'gls-klasse', 'murano', 'xc90', 'qashqai', 'nx', 'pajero-sport',
    'polo', 'prius', 'x7', 'x6', 'equus', 'gla-klasse-amg',
    'e-klasse-amg', 'xray', 'gt-r', '2115', 'auris', '3-serii', 'lancer',
    'acura', 'santa-fe', 'gs', 'karoq', 'ford', 'infiniti', 'mitsubishi',
    '4-serii', 'opel', 'daewoo', 'grand-vitara', 'i3', 'jaguar', 'octavia',
    '62', 'hilux', 'partner', 'niva', 'kalina', 'ravon', 'estima',
    'challenger', 'carnival', 'uaz', 'm8', 'superb', 'largus', 'nexia',
    'teana', 'amarok', 'm', 'rx', 'insignia', 'terrano', 'elantra',
    'cr-v', 'traveller', 'carina', 'malibu', 'arkana', 'q7', 'patrol',
    'scirocco', 'juke', 'passat', 'asx', 'mondeo', 'corolla-spacio',
    'grand-cherokee', 'lx'
]

# %%
# Фильтрация строк, оставляя только те, которые содержат значения
data = data[data['short_model'].isin(allowed_models)]

# %%
# Функция для замены символов в строках
def clean_string(s):
    if isinstance(s, str):
        return (s.replace(' ', '_')
                 .replace(',', '')
                 .replace('(', '')
                 .replace(')', '')
                 .replace('/', '')
                 .replace('-', '_')
                 .replace('\\', '_')
                 .replace('.', '_'))
    return s

# %%
# Применение функции ко всем элементам DataFrame
data = data.applymap(clean_string)

# %%
data['short_model'].unique()
# Out:
# array(['skoda', 'mercedes_benz', 'haval', 'kia', 'volkswagen', 'volvo',
#        'land_rover', 'renault', 'lada_vaz', 'nissan', 'toyota', 'bmw',
#        'lexus', 'honda', 'audi', 'porsche', 'mini', 'pajero', 'x3',
#        'peugeot', 'sportage', 'granta', 'hyundai', 'camry', '5_serii',
#        'rio', 'sorento', 'outlander', 'rav_4', 'solaris', 'wish',
#        'c_klasse', 'a6', '6', 'atlas', '308', 'e_klasse', 'land_cruiser',
#        'creta', 'a6_allroad', 'corolla', 'priora', '2121_4x4', 'lifan',
#        'chery', 'x5', 'duster', '1111_oka', 'geely', 'mazda', 'alphard',
#        'seltos', '3', 'almera', 'cruze', 'cx_5', 'note', 'chevrolet',
#        'h_1', 'i40', '100', 'lacetti', 'fortuner', 'land_cruiser_prado',
#        'cerato', 'pathfinder', 'k5', 'cayenne', 'meriva', 'a5', 'sonata',
#        'jolion', 'logan', 'tucson', 'subaru', 'range_rover', 'captur',
#        'maxima', 'x_trail', 'accent', 'vesta', 'gls_klasse', 'murano',
#        'xc90', 'qashqai', 'nx', 'pajero_sport', 'polo', 'prius', 'x7',
#        'x6', 'equus', 'gla_klasse_amg', 'e_klasse_amg', 'xray', 'gt_r',
#        '2115', 'auris', '3_serii', 'lancer', 'acura', 'santa_fe', 'gs',
#        'karoq', 'ford', 'infiniti', 'mitsubishi', '4_serii', 'opel',
#        'daewoo', 'grand_vitara', 'i3', 'jaguar', 'octavia', '62', 'hilux',
#        'partner', 'niva', 'kalina', 'ravon', 'estima', 'challenger',
#        'carnival', 'uaz', 'm8', 'superb', 'largus', 'nexia', 'teana',
#        'amarok', 'm', 'rx', 'insignia', 'terrano', 'elantra', 'cr_v',
#        'traveller', 'carina', 'malibu', 'arkana', 'q7', 'patrol',
#        'scirocco', 'juke', 'passat', 'asx', 'mondeo', 'corolla_spacio',
#        'grand_cherokee', 'lx'], dtype=object)

# %%
data.device_browser.unique()
# Out:
# array(['YaBrowser', 'Android_Webview', 'Chrome', 'Safari',
#        'Samsung_Internet', 'Safari_in_app', 'Opera', 'Android_Runtime',
#        'UC_Browser', 'Puffin', 'Instagram', 'Amazon_Silk',
#        'Android_Browser', 'Firefox', 'NokiaX2_02', 'Nokia501'],
#       dtype=object)

# %%
data.device_os.unique()
# Out:
# array(['Android', 'iOS', 'BlackBerry', 'Nokia', 'Windows_Phone'],
#       dtype=object)

# %%
# Проверяем количество пропусков в датасете
data.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# #### Признак `session_id` для построения модели нам не понадобится, удаляем его

# %%
# Удаление session_id
data.drop(columns=['session_id'], inplace=True)
data.head()
# Out:
#     visit_number            utm_source utm_medium device_category device_os  \
# 6              1  TxKUcPpthBDPieTGmVhx        cpc          tablet   Android
# 13             3  gVRrcxiDQubJiljoTbGm   referral          mobile   Android
# 31             1  ZpYIoDJMcFzVoPFsHGJL     banner          mobile   Android
# 40             6  kjsLglQLzykiRbcDiGcD        cpc          mobile       iOS
# 59             3  ZpYIoDJMcFzVoPFsHGJL     banner          mobile   Android
#
#    device_brand   device_browser geo_country          geo_city event_category  \
# 6        Lenovo        YaBrowser      Russia  Saint_Petersburg       card_web
# 13      Samsung  Android_Webview      Russia             Sochi       card_web
# 31       Xiaomi           Chrome      Russia  Saint_Petersburg       card_web
# 40        Apple           Safari      Russia            Moscow       card_web
# 59       Xiaomi           Chrome      Russia              Tula       card_web
#
#     event_action    short_model
# 6              0          skoda
# 13             0  mercedes_benz
# 31             0          haval
# 40             0  mercedes_benz
# 59             0            kia

# %% [markdown]
# #### Кодируем признаки

# %%
# Разделение категорий
cat_cols = data.select_dtypes(include='object').columns.to_list()
num_cols = ['visit_number']

# %%
cat_cols
# Out:
# ['utm_source',
#  'utm_medium',
#  'device_category',
#  'device_os',
#  'device_brand',
#  'device_browser',
#  'geo_country',
#  'geo_city',
#  'event_category',
#  'short_model']

# %%
num_cols
# Out:
# ['visit_number']

# %%
 # кодируем категориальные переменные
ohe = OneHotEncoder(handle_unknown='ignore',
                    sparse_output=False,
                    drop='first')
ohe
# Out:
# OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False)

# %%
ohe.fit(data[cat_cols])
# Out:
# OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False)

# %%
ohe_data = ohe.transform(data[cat_cols])
ohe_data.shape
# Out:
# (109490, 1266)

# %%
 # Выведим новые наименования признаков
feature_names = ohe.get_feature_names_out()
feature_names
# Out:
# array(['utm_source_ArbfvYgWhqxkzywKqpQf',
#        'utm_source_BAZCuyHZnaPrMGOMrcCQ',
#        'utm_source_BHcvLfOaCWvWTykYqHVe', ..., 'short_model_x_trail',
#        'short_model_xc90', 'short_model_xray'], dtype=object)

# %%
# Добавляем в исходный датафрейм получившиеся новые признаки
data[feature_names] = ohe_data
print(data.shape)
# Out:
# (109490, 1278)

# %%
# нормализация числовых признаков
std_scaler = StandardScaler()
std_scaler
# Out:
# StandardScaler()

# %%
std_scaler.fit(data[num_cols])
# Out:
# StandardScaler()

# %%
std_scaler_data = std_scaler.transform(data[num_cols])
std_scaler_data.shape
# Out:
# (109490, 1)

# %%
# Создаём наименования новых признаков
new_feature_names = [f"{col}_std" for col in num_cols]
new_feature_names
# Out:
# ['visit_number_std']

# %%
# Добавляем новые признаки в исходный датафрейм
data[new_feature_names] = std_scaler_data
data.shape
# Out:
# (109490, 1279)

# %%
# удаляем неинформативные колонки, либо колонки с утечкой данных
columns_for_drop = ['visit_number', 'utm_source','utm_medium',
                    'device_category','device_os','device_brand',
                    'device_browser','geo_country','geo_city',
                    'event_category','short_model']

# %%
data_prepared = data.drop(columns=columns_for_drop)
data_prepared.shape
# Out:
# (109490, 1268)

# %% [markdown]
# ### Подготовка признаков

# %%
# Разделение признаков
target = data_prepared['event_action']
features = data_prepared.drop('event_action', axis=1)

# %%
# Разделение выборок
X_train, X_test, y_train, y_test = train_test_split(features, target,
                                                    test_size=0.3,
                                                    stratify=target,
                                                    shuffle=True,
                                                    random_state=RS)
print(X_train.shape)
print(X_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# (76643, 1267)
# (32847, 1267)
# (76643,)
# (32847,)

# %%
# Сохраняем имена столбцов
column_names = X_train.columns.tolist()
column_names
# Out:
# ['utm_source_ArbfvYgWhqxkzywKqpQf',
#  'utm_source_BAZCuyHZnaPrMGOMrcCQ',
#  'utm_source_BHcvLfOaCWvWTykYqHVe',
#  'utm_source_BKeImrJuRDZcHiSSTdzm',
#  'utm_source_CFeqZLBNQdYHxJrTOHjY',
#  'utm_source_CXgqTLNTvvxWUWoOfjNF',
#  'utm_source_DlnuGwaJBHGNEKdWfOpe',
#  'utm_source_DnEUulZAecfGPvdtZBYS',
#  'utm_source_FTAuYVNoYYxgvKMpKSLW',
#  'utm_source_GmILPdZyuAVJCPsUBHeN',
#  'utm_source_GpAkIXsclxDGyILfNlrR',
#  'utm_source_HFaOtpcChAlcMuxEAlpu',
#  'utm_source_HVQdipMDpgJKXAzecwqn',
#  'utm_source_HbolMJUevblAbkHClEQa',
#  'utm_source_IRGUHqwEMepMjgCYBVRn',
#  'utm_source_ISrKoXQCxqqYvAZICvjs',
#  'utm_source_IZEXUFLARCUMynmHNBGo',
#  'utm_source_InLrxElufkSAvhfyFcOA',
#  'utm_source_KgicpPxiEQfzPlPwQZJq',
#  'utm_source_LkGnzVRewoaOHnMCwadT',
#  'utm_source_LlBOVIARRTjfgnQNjJre',
#  'utm_source_MQvSjpHGoGjbcBjfnLLm',
#  'utm_source_MvfHsxITijuriZxsqZqt',
#  'utm_source_NGNkCWwKgYFmiCCeZVxg',
#  'utm_source_NwLFDlNWnYxuLZEAZppl',
#  'utm_source_QxAxdyPLuQMEcrdZWdWb',
#  'utm_source_QzPMrfYhYSLYYPtPaBxI',
#  'utm_source_RAeIjhqmnmNXpLaHKdgp',
#  'utm_source_RmEBuqrriAfAVsLQQmhk',
#  'utm_source_RxecHElWobBxIeAkqFXV',
#  'utm_source_ShCnUddaAbEvEVCCZyOt',
#  'utm_source_SzZERoLMmrEUEhDaYcyN',
#  'utm_source_TTtiRKFZIaQpIWggfCoF',
#  'utm_source_TxKUcPpthBDPieTGmVhx',
#  'utm_source_UbQpozKfTgYxQovHjkQM',
#  'utm_source_WZxCpdfLzrgIfGUqxGpE',
#  'utm_source_XiUifkjKLLnomcDRhswp',
#  'utm_source_YclHumxPxSxgzHfvCaeF',
#  'utm_source_YlsczTIyBSwTLNtuDkCd',
#  'utm_source_ZHCJROlbqnkXTqIuVxnm',
#  'utm_source_ZpYIoDJMcFzVoPFsHGJL',
#  'utm_source_aXQzDWsJuGXeBXexNHjc',
#  'utm_source_azajeHUvPOKkHBvWFbjz',
#  'utm_source_bByPQxmDaMXgpHeypKSM',
#  'utm_source_bgTYkDHjOsJzMUtoGhiQ',
#  'utm_source_cAqxcRdSSFAyCPUxQHqy',
#  'utm_source_dGlVSdmIlgWDyOPjfwwy',
#  'utm_source_dyicZQGoeASogoSafjEh',
#  'utm_source_eLzNJHzPelJpEyBwMrKo',
#  'utm_source_eYRDXZIocNyHVjEHzesr',
#  'utm_source_eimRuUrNhZLAYcwRrNXu',
#  'utm_source_fRSoNoVhwXlxsbcAmZtb',
#  'utm_source_faqsogjxCvbseFqupueU',
#  'utm_source_fgymSoTvjKPEgaIJqsiH',
#  'utm_source_gPinzYOcsxiWLoYRKIhm',
#  'utm_source_gVRrcxiDQubJiljoTbGm',
#  'utm_source_geDcueAOghDzHkGMmdOq',
#  'utm_source_hJvOVTMdhkqIBqjVrsOL',
#  'utm_source_hTjLvqNxGggkGnxSCaTm',
#  'utm_source_iNFgfQPqHPBuvGCYtrQE',
#  'utm_source_jaSOmLICuBzCFqHfBdRg',
#  'utm_source_kjsLglQLzykiRbcDiGcD',
#  'utm_source_klTrhUaShgnjIbaPmqjc',
#  'utm_source_mNTexKeDdCADhrBgkEeA',
#  'utm_source_nSReTmyFtbSjlPrTKoaX',
#  'utm_source_ngkgBNjlzLYBofkljaBo',
#  'utm_source_nmfptFmSirEqNzAzqbXA',
#  'utm_source_nrKihqcWGIzDsOqljdAv',
#  'utm_source_oCqKpnSZJeYOVZTgTmKR',
#  'utm_source_oZCzWSykfixnjMPDNjSU',
#  'utm_source_pvCdohkUBGPPZOsCzVAu',
#  'utm_source_rgsINTLYFsElIlfRtNDP',
#  'utm_source_tjKUGseGMhkLEzdCqBRx',
#  'utm_source_uqttCIyjtWRiZIgdaLzw',
#  'utm_source_vFcAhRxLfOWKhvxjELkx',
#  'utm_source_vNNYHvZtTVtJICHsjBBL',
#  'utm_source_xEbgdGZJlqXAaRmeJQdW',
#  'utm_source_xQnKzPSrehWizZOmwHkM',
#  'utm_source_ySpKPVDYCgmkHVSeLjnJ',
#  'utm_source_zwpKjjsMoRVCdipntaHt',
#  'utm_medium_banner',
#  'utm_medium_blogger_channel',
#  'utm_medium_blogger_stories',
#  'utm_medium_clicks',
#  'utm_medium_cpa',
#  'utm_medium_cpc',
#  'utm_medium_cpm',
#  'utm_medium_email',
#  'utm_medium_fb_smm',
#  'utm_medium_google_cpc',
#  'utm_medium_info_text',
#  'utm_medium_landing',
#  'utm_medium_landing_interests',
#  'utm_medium_nkp',
#  'utm_medium_organic',
#  'utm_medium_outlook',
#  'utm_medium_partner',
#  'utm_medium_post',
#  'utm_medium_push',
#  'utm_medium_referral',
#  'utm_medium_smartbanner',
#  'utm_medium_smm',
#  'utm_medium_sms',
#  'utm_medium_static',
#  'utm_medium_tg',
#  'utm_medium_users_msk',
#  'utm_medium_vk_smm',
#  'utm_medium_yandex_cpc',
#  'device_category_mobile',
#  'device_category_tablet',
#  'device_os_BlackBerry',
#  'device_os_Nokia',
#  'device_os_Windows_Phone',
#  'device_os_iOS',
#  'device_brand_Acer',
#  'device_brand_Alcatel',
#  'device_brand_Amazon',
#  'device_brand_Ananda',
#  'device_brand_Apple',
#  'device_brand_Artel',
#  'device_brand_Asus',
#  'device_brand_BQ',
#  'device_brand_BlackBerry',
#  'device_brand_Black_Fox',
#  'device_brand_Blackview',
#  'device_brand_CAT',
#  'device_brand_Celkon',
#  'device_brand_Chuwi',
#  'device_brand_Coolpad',
#  'device_brand_Cubot',
#  'device_brand_DEXP',
#  'device_brand_DOOGEE',
#  'device_brand_Dark',
#  'device_brand_Elephone',
#  'device_brand_Fairphone',
#  'device_brand_Flexymove',
#  'device_brand_Fly',
#  'device_brand_Google',
#  'device_brand_Guophone',
#  'device_brand_HOMTOM',
#  'device_brand_HTC',
#  'device_brand_Highscreen',
#  'device_brand_Hisense',
#  'device_brand_Honor',
#  'device_brand_Huawei',
#  'device_brand_Infinix',
#  'device_brand_Inoi',
#  'device_brand_Karbonn',
#  'device_brand_Kata',
#  'device_brand_Kyocera',
#  'device_brand_LG',
#  'device_brand_LeEco',
#  'device_brand_LeTV',
#  'device_brand_Leagoo',
#  'device_brand_Lenovo',
#  'device_brand_MXQ',
#  'device_brand_MediaTek',
#  'device_brand_Meizu',
#  'device_brand_Micromax',
#  'device_brand_Mito',
#  'device_brand_Motorola',
#  'device_brand_Mozilla',
#  'device_brand_Neffos',
#  'device_brand_Nokia',
#  'device_brand_Nomu',
#  'device_brand_OPPO',
#  'device_brand_OnePlus',
#  'device_brand_Oukitel',
#  'device_brand_POCO',
#  'device_brand_Panasonic',
#  'device_brand_Philips',
#  'device_brand_Prestigio',
#  'device_brand_QMobile',
#  'device_brand_Realme',
#  'device_brand_Samsung',
#  'device_brand_Sharp',
#  'device_brand_Smartisan',
#  'device_brand_Sony',
#  'device_brand_TCL',
#  'device_brand_TP_Link',
#  'device_brand_Teclast',
#  'device_brand_Tecno',
#  'device_brand_TurboPad',
#  'device_brand_Ulefone',
#  'device_brand_Umidigi',
#  'device_brand_Unihertz',
#  'device_brand_Vertex',
#  'device_brand_Vivo',
#  'device_brand_Vsmart',
#  'device_brand_Wiko',
#  'device_brand_Wileyfox',
#  'device_brand_Xiaomi',
#  'device_brand_Yuntab',
#  'device_brand_ZOJI',
#  'device_brand_ZTE',
#  'device_brand_itel',
#  'device_browser_Android_Browser',
#  'device_browser_Android_Runtime',
#  'device_browser_Android_Webview',
#  'device_browser_Chrome',
#  'device_browser_Firefox',
#  'device_browser_Instagram',
#  'device_browser_Nokia501',
#  'device_browser_NokiaX2_02',
#  'device_browser_Opera',
#  'device_browser_Puffin',
#  'device_browser_Safari',
#  'device_browser_Safari_in_app',
#  'device_browser_Samsung_Internet',
#  'device_browser_UC_Browser',
#  'device_browser_YaBrowser',
#  'geo_country_Armenia',
#  'geo_country_Australia',
#  'geo_country_Austria',
#  'geo_country_Azerbaijan',
#  'geo_country_Bahrain',
#  'geo_country_Bangladesh',
#  'geo_country_Belarus',
#  'geo_country_Belgium',
#  'geo_country_Brazil',
#  'geo_country_Bulgaria',
#  'geo_country_Cambodia',
#  'geo_country_Canada',
#  'geo_country_Colombia',
#  'geo_country_Croatia',
#  'geo_country_Cuba',
#  'geo_country_Cyprus',
#  'geo_country_Czechia',
#  'geo_country_Denmark',
#  'geo_country_Dominican_Republic',
#  'geo_country_Egypt',
#  'geo_country_Estonia',
#  'geo_country_Faroe_Islands',
#  'geo_country_Finland',
#  'geo_country_France',
#  'geo_country_French_Guiana',
#  'geo_country_Georgia',
#  'geo_country_Germany',
#  'geo_country_Gibraltar',
#  'geo_country_Greece',
#  'geo_country_Hungary',
#  'geo_country_India',
#  'geo_country_Indonesia',
#  'geo_country_Iran',
#  'geo_country_Iraq',
#  'geo_country_Ireland',
#  'geo_country_Israel',
#  'geo_country_Italy',
#  'geo_country_Kazakhstan',
#  'geo_country_Kenya',
#  'geo_country_Kyrgyzstan',
#  'geo_country_Latvia',
#  'geo_country_Libya',
#  'geo_country_Lithuania',
#  'geo_country_Luxembourg',
#  'geo_country_Madagascar',
#  'geo_country_Malaysia',
#  'geo_country_Maldives',
#  'geo_country_Mauritius',
#  'geo_country_Mexico',
#  'geo_country_Moldova',
#  'geo_country_Mongolia',
#  'geo_country_Montenegro',
#  'geo_country_Morocco',
#  'geo_country_Myanmar_Burma',
#  'geo_country_Netherlands',
#  'geo_country_New_Zealand',
#  'geo_country_Nigeria',
#  'geo_country_Norway',
#  'geo_country_Pakistan',
#  'geo_country_Poland',
#  'geo_country_Portugal',
#  'geo_country_Qatar',
#  'geo_country_Romania',
#  'geo_country_Russia',
#  'geo_country_Saudi_Arabia',
#  'geo_country_Senegal',
#  'geo_country_Serbia',
#  'geo_country_Singapore',
#  'geo_country_Slovakia',
#  'geo_country_South_Korea',
#  'geo_country_Spain',
#  'geo_country_Sri_Lanka',
#  'geo_country_Sweden',
#  'geo_country_Switzerland',
#  'geo_country_Syria',
#  'geo_country_Tajikistan',
#  'geo_country_Tanzania',
#  'geo_country_Thailand',
#  'geo_country_Turkey',
#  'geo_country_Turkmenistan',
#  'geo_country_Uganda',
#  'geo_country_Ukraine',
#  'geo_country_United_Arab_Emirates',
#  'geo_country_United_Kingdom',
#  'geo_country_United_States',
#  'geo_country_Uzbekistan',
#  'geo_country_Venezuela',
#  'geo_country_Vietnam',
#  'geo_city_13403',
#  'geo_city_24130',
#  'geo_city_53425',
#  'geo_city_6784',
#  'geo_city_75709',
#  'geo_city_7668',
#  'geo_city_83709',
#  'geo_city_Abakan',
#  'geo_city_Abu_Dhabi',
#  'geo_city_Abuja',
#  'geo_city_Achinsk',
#  'geo_city_Adana',
#  'geo_city_Aksay',
#  'geo_city_Aktobe',
#  'geo_city_Alanya',
#  "geo_city_Alchevs'k",
#  'geo_city_Alexandria',
#  'geo_city_Alexandrov',
#  'geo_city_Alfredo_V__Bonfil',
#  'geo_city_Algeciras',
#  'geo_city_Almaty',
#  'geo_city_Almetyevsk',
#  'geo_city_Altoona',
#  'geo_city_Alushta',
#  'geo_city_Amsterdam',
#  'geo_city_Amvrosiivka',
#  'geo_city_Anapa',
#  'geo_city_Andijan',
#  'geo_city_Angarsk',
#  'geo_city_Ankara',
#  'geo_city_Antalya',
#  'geo_city_Antananarivo',
#  'geo_city_Antwerp',
#  'geo_city_Apatity',
#  'geo_city_Aprelevka',
#  'geo_city_Aramil',
#  'geo_city_Argun',
#  'geo_city_Arkhangelsk',
#  'geo_city_Armavir',
#  "geo_city_Armyans'k",
#  'geo_city_Arsenyev',
#  'geo_city_Artemovskiy',
#  'geo_city_Artyom',
#  'geo_city_Arzamas',
#  'geo_city_Asbest',
#  'geo_city_Ashburn',
#  'geo_city_Ashgabat',
#  'geo_city_Aspen_Hill',
#  'geo_city_Astrakhan',
#  'geo_city_Athens',
#  'geo_city_Atlanta',
#  'geo_city_Atyrau',
#  'geo_city_Augsburg',
#  'geo_city_Azov',
#  'geo_city_Babruysk',
#  'geo_city_Badajoz',
#  'geo_city_Baghdad',
#  'geo_city_Bakhchysarai',
#  'geo_city_Baku',
#  'geo_city_Balakovo',
#  'geo_city_Balashikha',
#  'geo_city_Ballerup',
#  'geo_city_Bangkok',
#  'geo_city_Barcelona',
#  'geo_city_Barnaul',
#  'geo_city_Barysaw',
#  'geo_city_Bataysk',
#  'geo_city_Batu_Caves',
#  'geo_city_Batumi',
#  'geo_city_Bavly',
#  'geo_city_Belaya_Kalitva',
#  'geo_city_Belgorod',
#  'geo_city_Belgrade',
#  'geo_city_Beloozyorskiy',
#  'geo_city_Belorechensk',
#  'geo_city_Belovo',
#  'geo_city_Bengaluru',
#  'geo_city_Benghazi',
#  'geo_city_Beni_Suef',
#  'geo_city_Benidorm',
#  'geo_city_Berdsk',
#  "geo_city_Berdyans'k",
#  'geo_city_Berezniki',
#  'geo_city_Bergamo',
#  'geo_city_Berlin',
#  'geo_city_Beryozovsky',
#  'geo_city_Beslan',
#  "geo_city_Bilohirs'k",
#  'geo_city_Birmingham',
#  'geo_city_Birobidzhan',
#  'geo_city_Bishkek',
#  'geo_city_Biysk',
#  'geo_city_Blagoveshchensk',
#  'geo_city_Bobrovskiy',
#  'geo_city_Bodrum',
#  'geo_city_Bogota',
#  'geo_city_Bollnas',
#  'geo_city_Bologoye',
#  'geo_city_Bolshoy_Kamen',
#  'geo_city_Bor',
#  'geo_city_Borisoglebsk',
#  'geo_city_Borovichi',
#  'geo_city_Boston',
#  'geo_city_Bratislava',
#  'geo_city_Bratsk',
#  'geo_city_Bremen',
#  'geo_city_Brest',
#  'geo_city_Bridgeport',
#  'geo_city_Brisbane',
#  'geo_city_Brixen',
#  'geo_city_Brussels',
#  'geo_city_Bryanka',
#  'geo_city_Bryansk',
#  'geo_city_Bryukhovetskaya',
#  'geo_city_Bucharest',
#  'geo_city_Budapest',
#  'geo_city_Budva',
#  'geo_city_Burgas',
#  'geo_city_Buynaksk',
#  'geo_city_Cairo',
#  'geo_city_Cannes',
#  'geo_city_Caracas',
#  'geo_city_Carlow',
#  'geo_city_Casablanca',
#  'geo_city_Chania',
#  'geo_city_Chebarkul',
#  'geo_city_Cheboksary',
#  'geo_city_Chegem',
#  'geo_city_Chekhov',
#  'geo_city_Chelyabinsk',
#  'geo_city_Chennai',
#  'geo_city_Cherepovets',
#  'geo_city_Cherkessk',
#  'geo_city_Chernivtsi',
#  'geo_city_Chernogolovka',
#  'geo_city_Chicago',
#  'geo_city_Chisinau',
#  'geo_city_Chistopol',
#  'geo_city_Chita',
#  "geo_city_Chornomors'ke",
#  'geo_city_Christchurch',
#  'geo_city_Chusovskoye_Urban_Settlement',
#  'geo_city_Cinisello_Balsamo',
#  'geo_city_Clifton',
#  'geo_city_Coffeyville',
#  'geo_city_Cologne',
#  'geo_city_Colombo',
#  'geo_city_Columbus',
#  'geo_city_Conroe',
#  'geo_city_Copenhagen',
#  'geo_city_Croydon',
#  'geo_city_Da_Nang',
#  'geo_city_Dakar',
#  'geo_city_Dallas',
#  'geo_city_Damascus',
#  'geo_city_Dar_es_Salaam',
#  'geo_city_Dartford',
#  'geo_city_Dedovsk',
#  'geo_city_Derbent',
#  'geo_city_Dhaka',
#  'geo_city_Dijon',
#  'geo_city_Dimitrovgrad',
#  'geo_city_Dmitrov',
#  'geo_city_Doha',
#  'geo_city_Dolgoprudny',
#  'geo_city_Domodedovo',
#  'geo_city_Donetsk',
#  'geo_city_Dorokhovskoja',
#  'geo_city_Dovzhansk',
#  'geo_city_Dubai',
#  'geo_city_Dublin',
#  'geo_city_Dubna',
#  'geo_city_Dubovoe',
#  'geo_city_Dushanbe',
#  'geo_city_Dusseldorf',
#  'geo_city_Dzerzhinsk',
#  'geo_city_Dzerzhinsky',
#  'geo_city_Dzhankoi',
#  'geo_city_Eindhoven',
#  'geo_city_Elektrostal',
#  'geo_city_Elektrougli',
#  'geo_city_Elista',
#  'geo_city_Ely',
#  'geo_city_Empuriabrava',
#  'geo_city_Enem',
#  'geo_city_Engels',
#  'geo_city_Epsom',
#  'geo_city_Espoo',
#  'geo_city_Essentuki',
#  'geo_city_Falkensee',
#  'geo_city_Famagusta',
#  'geo_city_Feodosiya',
#  'geo_city_Fislisbach',
#  'geo_city_Fontainebleau',
#  'geo_city_Forest_City',
#  'geo_city_Fort_Lauderdale',
#  'geo_city_Fort_Worth',
#  'geo_city_Frankfurt',
#  'geo_city_Frolovo',
#  'geo_city_Fryazino',
#  'geo_city_Funchal',
#  'geo_city_Gandia',
#  'geo_city_Garmisch_Partenkirchen',
#  'geo_city_Gatchina',
#  'geo_city_Gelendzhik',
#  'geo_city_Geneva',
#  'geo_city_Genoa',
#  'geo_city_Gibraltar',
#  'geo_city_Giza',
#  'geo_city_Glazov',
#  'geo_city_Glendale',
#  'geo_city_Gloucester',
#  'geo_city_Golitsyno',
#  'geo_city_Gomel',
#  'geo_city_Gorki_2',
#  'geo_city_Gorno_Altaysk',
#  'geo_city_Gothenburg',
#  'geo_city_Goynuk',
#  'geo_city_Greensboro',
#  'geo_city_Greven',
#  'geo_city_Grodno',
#  'geo_city_Gross_Umstadt',
#  'geo_city_Grozny',
#  'geo_city_Gudermes',
#  'geo_city_Gus_Khrustalny',
#  'geo_city_Haarlem',
#  'geo_city_Haifa',
#  'geo_city_Hamburg',
#  'geo_city_Hanoi',
#  'geo_city_Haspra',
#  'geo_city_Havana',
#  'geo_city_Havelock_Belmont_Methuen',
#  'geo_city_Helsinki',
#  'geo_city_Heviz',
#  'geo_city_Ho_Chi_Minh_City',
#  'geo_city_Hollywood',
#  'geo_city_Hombrechtikon',
#  'geo_city_Horley',
#  'geo_city_Horlivka',
#  "geo_city_Hresivs'kyi",
#  'geo_city_Hurghada',
#  'geo_city_Ibiza',
#  "geo_city_Industrial'nyy",
#  'geo_city_Irkutsk',
#  'geo_city_Isfahan',
#  'geo_city_Ishimbay',
#  'geo_city_Iskitim',
#  'geo_city_Islamabad',
#  'geo_city_Istanbul',
#  'geo_city_Istra',
#  'geo_city_Ivanovo',
#  'geo_city_Ivanteyevka',
#  'geo_city_Izhevsk',
#  'geo_city_Izmail',
#  'geo_city_Izmir',
#  'geo_city_Jakarta',
#  'geo_city_Johor_Bahru',
#  'geo_city_Kalininets',
#  'geo_city_Kaliningrad',
#  'geo_city_Kaluga',
#  'geo_city_Kamensk_Shakhtinsky',
#  'geo_city_Kamensk_Uralsky',
#  'geo_city_Kamianske',
#  'geo_city_Kampala',
#  'geo_city_Kamyshin',
#  'geo_city_Kandalaksha',
#  'geo_city_Kanevskaya',
#  'geo_city_Kansas_City',
#  'geo_city_Kansk',
#  'geo_city_Karagandy',
#  'geo_city_Karon',
#  'geo_city_Kashira',
#  'geo_city_Kaspiysk',
#  'geo_city_Katav_Ivanovsk',
#  'geo_city_Katowice',
#  'geo_city_Kayseri',
#  'geo_city_Kazan',
#  'geo_city_Kemer',
#  'geo_city_Kemerovo',
#  'geo_city_Kerch',
#  'geo_city_Khabarovsk',
#  'geo_city_Khanty_Mansiysk',
#  'geo_city_Kharkiv',
#  'geo_city_Khasavyurt',
#  'geo_city_Khimki',
#  'geo_city_Khotkovo',
#  'geo_city_Khotyn',
#  'geo_city_Khrestivka',
#  'geo_city_Khrustalnyi',
#  'geo_city_Kielce',
#  'geo_city_Kikinda',
#  'geo_city_Kimry',
#  'geo_city_Kinel',
#  'geo_city_Kineshma',
#  'geo_city_Kingisepp',
#  'geo_city_Kingston',
#  'geo_city_Kirishi',
#  'geo_city_Kirov',
#  'geo_city_Kirovsk',
#  'geo_city_Kirzhach',
#  'geo_city_Kiselyovsk',
#  'geo_city_Kislovodsk',
#  'geo_city_Kizilyurt',
#  'geo_city_Kizlyar',
#  'geo_city_Klimovsk',
#  'geo_city_Klin',
#  'geo_city_Kolchugino',
#  'geo_city_Kolomna',
#  'geo_city_Kommunar',
#  'geo_city_Komsomolsk_on_Amur',
#  'geo_city_Konakovo',
#  'geo_city_Kopeysk',
#  'geo_city_Korenovsk',
#  'geo_city_Korkino',
#  'geo_city_Korolyov',
#  'geo_city_Kostanay',
#  'geo_city_Kostomuksha',
#  'geo_city_Kostroma',
#  'geo_city_Kotelniki',
#  'geo_city_Kotlas',
#  'geo_city_Kotor_Municipality',
#  'geo_city_Kourou',
#  'geo_city_Kovrov',
#  'geo_city_Kraskovo',
#  'geo_city_Krasnoarmeysk',
#  'geo_city_Krasnodar',
#  'geo_city_Krasnogorsk',
#  "geo_city_Krasnoperekops'k",
#  'geo_city_Krasnoturyinsk',
#  'geo_city_Krasnoyarsk',
#  'geo_city_Krasnoznamensk',
#  'geo_city_Kratovo',
#  'geo_city_Kropotkin',
#  'geo_city_Kryvyi_Rih',
#  'geo_city_Kstovo',
#  'geo_city_Kubinka',
#  'geo_city_Kumertau',
#  'geo_city_Kuopio',
#  'geo_city_Kurchatov',
#  'geo_city_Kurgan',
#  'geo_city_Kurovskoye',
#  'geo_city_Kursk',
#  'geo_city_Kurumoch',
#  'geo_city_Kushchyovskaya',
#  'geo_city_Kyiv',
#  'geo_city_Kyshtym',
#  'geo_city_Kyzyl',
#  'geo_city_Labytnangi',
#  'geo_city_Lancy',
#  'geo_city_Las_Palmas_de_Gran_Canaria',
#  'geo_city_Las_Vegas',
#  'geo_city_Leeds',
#  'geo_city_Leipzig',
#  'geo_city_Leninsk_Kuznetskiy',
#  'geo_city_Lesnoy_Gorodok',
#  'geo_city_Lida',
#  'geo_city_Liege',
#  'geo_city_Liepaja',
#  'geo_city_Limassol',
#  'geo_city_Lipetsk',
#  'geo_city_Lipitsy',
#  'geo_city_Lobnya',
#  'geo_city_Lodeynoye_Pole',
#  'geo_city_Lodz',
#  'geo_city_London',
#  'geo_city_Los_Angeles',
#  'geo_city_Losino_Petrovsky',
#  'geo_city_Luanda',
#  'geo_city_Lugano',
#  'geo_city_Luhansk',
#  'geo_city_Lukhovitsy',
#  'geo_city_Lulea',
#  'geo_city_Luxembourg',
#  'geo_city_Lviv',
#  'geo_city_Lyon',
#  'geo_city_Lysva',
#  'geo_city_Lytkarino',
#  'geo_city_Lyuban',
#  'geo_city_Lyubertsy',
#  'geo_city_Maasvlakte_Rotterdam',
#  'geo_city_Madrid',
#  'geo_city_Magadan',
#  'geo_city_Magnitogorsk',
#  'geo_city_Mai_Khao',
#  'geo_city_Makhachkala',
#  'geo_city_Makiivka',
#  'geo_city_Malakhovka',
#  'geo_city_Male',
#  'geo_city_Malmo',
#  'geo_city_Maloyaroslavets',
#  'geo_city_Manama',
#  'geo_city_Manavgat',
#  'geo_city_Mandalay',
#  "geo_city_Mariupol'",
#  'geo_city_Markham',
#  'geo_city_Marks',
#  'geo_city_Marmaris',
#  'geo_city_Marseille',
#  'geo_city_Maykop',
#  'geo_city_Mechelen',
#  'geo_city_Megion',
#  'geo_city_Meleuz',
#  'geo_city_Menton',
#  'geo_city_Mersin',
#  'geo_city_Metz',
#  'geo_city_Mezhdurechensk',
#  'geo_city_Miami',
#  'geo_city_Miami_Beach',
#  'geo_city_Miass',
#  'geo_city_Mikhaylovka',
#  'geo_city_Mikkeli_Province',
#  'geo_city_Milan',
#  'geo_city_Mineralnye_Vody',
#  'geo_city_Minsk',
#  'geo_city_Minusinsk',
#  'geo_city_Mirny',
#  'geo_city_Mogilev',
#  'geo_city_Monchegorsk',
#  'geo_city_Monino',
#  'geo_city_Monroe_Township',
#  'geo_city_Montpellier',
#  'geo_city_Monza',
#  'geo_city_Moscow',
#  'geo_city_Mozhaysk',
#  'geo_city_Mozhga',
#  'geo_city_Munich',
#  'geo_city_Murmansk',
#  'geo_city_Murom',
#  'geo_city_Mykolaiv',
#  'geo_city_Mytishchi',
#  'geo_city_Naaldwijk',
#  'geo_city_Naberezhnye_Chelny',
#  'geo_city_Nadym',
#  'geo_city_Nairobi',
#  'geo_city_Nakhabino',
#  'geo_city_Nakhodka',
#  'geo_city_Nalchik',
#  'geo_city_Namangan',
#  'geo_city_Naples',
#  'geo_city_Naro_Fominsk',
#  'geo_city_Narva',
#  'geo_city_Naryan_Mar',
#  'geo_city_Nazran',
#  'geo_city_Neftekamsk',
#  'geo_city_Nefteyugansk',
#  'geo_city_Neryungri',
#  'geo_city_Netanya',
#  'geo_city_Nevinnomyssk',
#  'geo_city_New_Cairo_City',
#  'geo_city_New_Delhi',
#  'geo_city_New_York',
#  'geo_city_Nice',
#  'geo_city_Nicosia',
#  'geo_city_Nikolskoye',
#  'geo_city_Nizhnekamsk',
#  'geo_city_Nizhnevartovsk',
#  'geo_city_Nizhny_Novgorod',
#  'geo_city_Nizhny_Tagil',
#  'geo_city_Noginsk',
#  'geo_city_Nogliki',
#  'geo_city_Norfolk',
#  'geo_city_Norilsk',
#  'geo_city_North_Kuta',
#  'geo_city_Novaya_Adygeya',
#  'geo_city_Novoaltaysk',
#  'geo_city_Novocheboksarsk',
#  'geo_city_Novocherkassk',
#  'geo_city_Novokuznetsk',
#  'geo_city_Novomoskovsk',
#  'geo_city_Novorossiysk',
#  'geo_city_Novoshakhtinsk',
#  'geo_city_Novosibirsk',
#  'geo_city_Novotitarovskaya',
#  'geo_city_Novotroitsk',
#  'geo_city_Novouralsk',
#  'geo_city_Novoye_Devyatkino',
#  'geo_city_Novy_Urengoy',
#  'geo_city_Noyabrsk',
#  'geo_city_Nur_Sultan',
#  'geo_city_Nyagan',
#  'geo_city_Nyzhnya_Krynka',
#  'geo_city_Obninsk',
#  'geo_city_Odesa',
#  'geo_city_Odintsovo',
#  'geo_city_Oktyabrsky',
#  'geo_city_Olching',
#  'geo_city_Omsk',
#  'geo_city_Orekhovo_Zuyevo',
#  'geo_city_Orenburg',
#  'geo_city_Orsk',
#  'geo_city_Oryol',
#  'geo_city_Osh',
#  'geo_city_Oslo_Municipality',
#  'geo_city_Ottawa',
#  "geo_city_Ovidiopol'",
#  'geo_city_Oyster_Bay',
#  'geo_city_Ozersk',
#  'geo_city_Pabna',
#  'geo_city_Pak_Phriao',
#  'geo_city_Palisades_Park',
#  'geo_city_Paris',
#  'geo_city_Parma',
#  'geo_city_Parndorf',
#  'geo_city_Pattaya_City',
#  'geo_city_Pavlodar',
#  'geo_city_Pavlovo',
#  'geo_city_Pavlovsky_Posad',
#  'geo_city_Payallar',
#  'geo_city_Pechora',
#  'geo_city_Penza',
#  'geo_city_Pereslavl_Zalessky',
#  "geo_city_Pereval's'k",
#  'geo_city_Perm',
#  'geo_city_Pervouralsk',
#  'geo_city_Peterborough',
#  'geo_city_Petropavl',
#  'geo_city_Petropavlovsk_Kamchatskiy',
#  'geo_city_Petrovo_Dalneye',
#  'geo_city_Petrozavodsk',
#  'geo_city_Philadelphia',
#  'geo_city_Phnom_Penh',
#  'geo_city_Phoenix',
#  'geo_city_Phuket',
#  'geo_city_Pinsk',
#  'geo_city_Pireas',
#  'geo_city_Pleasanton',
#  'geo_city_Podgorica',
#  'geo_city_Podolsk',
#  'geo_city_Polatsk',
#  'geo_city_Polevskoy',
#  'geo_city_Poltava',
#  'geo_city_Poltavskaya',
#  'geo_city_Polysayevo',
#  'geo_city_Poronaysk',
#  'geo_city_Port_Louis',
#  'geo_city_Porto',
#  'geo_city_Potsdam',
#  'geo_city_Povarovo',
#  'geo_city_Poznan',
#  'geo_city_Prague',
#  'geo_city_Prineville',
#  'geo_city_Priozersk',
#  'geo_city_Prokhladny',
#  'geo_city_Prokopyevsk',
#  'geo_city_Protvino',
#  'geo_city_Pskov',
#  'geo_city_Purcellville',
#  'geo_city_Pushkino',
#  'geo_city_Pyatigorsk',
#  "geo_city_Ra'anana",
#  'geo_city_Rabat',
#  'geo_city_Ramenskoye',
#  'geo_city_Rangpur',
#  'geo_city_Ras_Al_Khaimah',
#  'geo_city_Reading',
#  'geo_city_Reutlingen',
#  'geo_city_Reutov',
#  'geo_city_Revda',
#  'geo_city_Riga',
#  'geo_city_Rishon_LeTsiyon',
#  'geo_city_Riyadh',
#  'geo_city_Rodniki',
#  'geo_city_Rome',
#  'geo_city_Rossosh',
#  'geo_city_Rostov',
#  'geo_city_Rostov_on_Don',
#  'geo_city_Rotterdam',
#  "geo_city_Roven'ky",
#  'geo_city_Rubizhne',
#  'geo_city_Rubtsovsk',
#  'geo_city_Ruza',
#  'geo_city_Ruzayevka',
#  'geo_city_Ryazan',
#  'geo_city_Rybinsk',
#  'geo_city_Saalfelden',
#  'geo_city_Safonovo',
#  'geo_city_Saint_Arsene',
#  'geo_city_Saint_Denis',
#  'geo_city_Saint_Genis_Pouilly',
#  'geo_city_Saint_Petersburg',
#  'geo_city_Saky',
#  'geo_city_Salavat',
#  'geo_city_Salekhard',
#  'geo_city_Samara',
#  'geo_city_Samarkand',
#  'geo_city_Samarskoye',
#  'geo_city_San_Antonio',
#  'geo_city_San_Francisco',
#  'geo_city_San_Jose',
#  'geo_city_San_Pedro_Garza_Garcia',
#  'geo_city_Sankt_Ingbert',
#  'geo_city_Santa_Clara',
#  'geo_city_Santo_Domingo',
#  'geo_city_Sao_Paulo',
#  'geo_city_Saransk',
#  'geo_city_Sarapul',
#  'geo_city_Saratov',
#  'geo_city_Sarov',
#  'geo_city_Satka',
#  'geo_city_Scottsdale',
#  'geo_city_Seattle',
#  'geo_city_Selyatino',
#  'geo_city_Semender',
#  'geo_city_Senigallia',
#  'geo_city_Seoul',
#  'geo_city_Sergiyev_Posad',
#  'geo_city_Serov',
#  'geo_city_Serpukhov',
#  'geo_city_Sertolovo',
#  'geo_city_Sevastopol',
#  'geo_city_Severodvinsk',
#  'geo_city_Severomorsk',
#  'geo_city_Seversk',
#  'geo_city_Seville',
#  'geo_city_Shadrinsk',
#  'geo_city_Shakhovskaya',
#  'geo_city_Shakhty',
#  'geo_city_Sharjah',
#  'geo_city_Sharm_El_Sheikh',
#  'geo_city_Shatura',
#  'geo_city_Shchyokino',
#  'geo_city_Shchyolkovo',
#  'geo_city_Shelekhov',
#  'geo_city_Shiraz',
#  'geo_city_Shlisselburg',
#  'geo_city_Shuya',
#  'geo_city_Shymkent',
#  'geo_city_Sibay',
#  'geo_city_Side',
#  'geo_city_Siegen',
#  'geo_city_Simferopol',
#  'geo_city_Singapore',
#  'geo_city_Singen',
#  'geo_city_Slavgorod',
#  'geo_city_Slavyansk_na_Kubani',
#  'geo_city_Smolensk',
#  'geo_city_Snezhinsk',
#  'geo_city_Sochi',
#  'geo_city_Soest',
#  'geo_city_Sofia',
#  'geo_city_Solnechnogorsk',
#  'geo_city_Sorokyne',
#  'geo_city_Sosnovoborsk',
#  'geo_city_Sosnovy_Bor',
#  "geo_city_Sovjets'kyi",
#  'geo_city_Spassk_Dalny',
#  'geo_city_Split',
#  'geo_city_St_Laurent_du_Var',
#  'geo_city_Staraya_Kupavna',
#  'geo_city_Starnikovo',
#  'geo_city_Stary_Oskol',
#  'geo_city_Stavropol',
#  'geo_city_Sterlitamak',
#  'geo_city_Stockholm',
#  'geo_city_Strasbourg',
#  'geo_city_Strovolos',
#  'geo_city_Stupino',
#  'geo_city_Stuttgart',
#  'geo_city_Sudak',
#  'geo_city_Suez',
#  'geo_city_Sunny_Beach',
#  'geo_city_Sunnyvale',
#  'geo_city_Sunset_Beach',
#  'geo_city_Surgut',
#  'geo_city_Surrey',
#  'geo_city_Syktyvkar',
#  'geo_city_Taganrog',
#  'geo_city_Tallinn',
#  'geo_city_Tambov',
#  'geo_city_Taraz',
#  'geo_city_Tashkent',
#  'geo_city_Tbilisi',
#  'geo_city_Tehran',
#  'geo_city_Tekirova',
#  'geo_city_Tel_Aviv_Yafo',
#  'geo_city_Temirtau',
#  'geo_city_Temryuk',
#  'geo_city_The_Hague',
#  'geo_city_Thessaloniki',
#  'geo_city_Tikhoretsk',
#  'geo_city_Tikhvin',
#  'geo_city_Tiraspol',
#  'geo_city_Tolyatti',
#  'geo_city_Tomilino',
#  'geo_city_Tomsk',
#  'geo_city_Toronto',
#  'geo_city_Torshavn',
#  'geo_city_Torzhok',
#  'geo_city_Tosno',
#  'geo_city_Troedobelikovskiy',
#  'geo_city_Trudovoye',
#  'geo_city_Tuapse',
#  'geo_city_Tuchkovo',
#  'geo_city_Tula',
#  'geo_city_Tuymazy',
#  'geo_city_Tver',
#  'geo_city_Tynda',
#  'geo_city_Tyumen',
#  'geo_city_Uchaly',
#  'geo_city_Ufa',
#  'geo_city_Ukhta',
#  ...]

# %% [markdown]
# #### Для тренировочной выборки применяем оверсэмплинг для балансировки классов. Для этого используем RandomOverSampler, который увеличивает количество образцов в недопредставленных классах путем случайного дублирования существующих образцов до достижения равномерного распределения классов.

# %%
print('Распределение классов до оверсэмплинга:', y_train.value_counts())
ros = RandomOverSampler(sampling_strategy='not majority', random_state=RS)
X_train2, y_train2 = ros.fit_resample(X_train, y_train)
print('Распределение классов после оверсэмплинга:', y_train2.value_counts())
# Out:
# Распределение классов до оверсэмплинга: event_action
# 0    76255
# 1      388
# Name: count, dtype: int64
# Распределение классов после оверсэмплинга: event_action
# 0    76255
# 1    76255
# Name: count, dtype: int64

# %% [markdown]
# ## Моделирование

# %%
# Задаём эталон в виде оценки dummy классификатора со стратегией стратификации и оценкой на тесте.  
dummy = DummyClassifier(strategy='stratified', random_state=RS)
dummy.fit(X_train2, y_train2)
y_hat = dummy.predict(X_test)
print(roc_auc_score(y_test,y_hat))
# Out:
# 0.45479632799426956

# %%
# Настройка PCA для уменьшения размерности
pca = PCA(n_components=0.95)  # Оставляем 95% дисперсии

# %% [markdown]
# #### Обучение моделей

# %%
# %%time
mlp = MLPClassifier(random_state=RS)

pipeline = ImbPipeline([
    ('pca', pca),
    ('oversampler', ros),
    ('classifier', mlp)
])

kf = KFold(n_splits=5, shuffle=True, random_state=RS)

scores_mlp = cross_val_score(pipeline, X_train, y_train, cv=kf, scoring='roc_auc')

print("ROC-AUC для каждого фолда: ", scores_mlp)
print("Средняя оценка ROC-AUC: ", scores_mlp.mean())
# Out:
# ROC-AUC для каждого фолда:  [0.96650292 0.95670457 0.9739339  0.9741316  0.98925151]
# Средняя оценка ROC-AUC:  0.9721048997275288
# CPU times: total: 12min 17s
# Wall time: 6min 54s

# %%
# %%time
gb = GradientBoostingClassifier(random_state=RS,
                                n_estimators=300,
                                min_samples_leaf=50,
                                max_depth=5)

pipeline1 = ImbPipeline([
    ('pca', pca),
    ('oversampler', ros),
    ('classifier', gb)
])

kf = KFold(n_splits=5, shuffle=True, random_state=RS)

scores_gb = cross_val_score(pipeline1, X_train, y_train, cv=kf, scoring='roc_auc')

print("ROC-AUC для каждого фолда: ", scores_gb)
print("Средняя оценка ROC-AUC: ", scores_gb.mean())
# Out:
# ROC-AUC для каждого фолда:  [0.99707354 0.98807872 0.99901976 0.99884651 0.99901134]
# Средняя оценка ROC-AUC:  0.9964059721816747
# CPU times: total: 31min 14s
# Wall time: 1h 17min 5s

# %%
# %%time
rf = RandomForestClassifier(random_state=RS,
                            max_features='log2', 
                            min_samples_leaf=1, 
                            n_estimators=300)

pipeline2 = ImbPipeline([
    ('pca', pca),
    ('oversampler', ros),
    ('classifier', rf)
])

kf = KFold(n_splits=5, shuffle=True, random_state=RS)

scores_rf = cross_val_score(pipeline2, X_train, y_train, cv=kf, scoring='roc_auc')

print("ROC-AUC для каждого фолда: ", scores_rf)
print("Средняя оценка ROC-AUC: ", scores_rf.mean())
# Out:
# ROC-AUC для каждого фолда:  [0.99862764 0.99818089 0.99865703 0.99910024 0.99820276]
# Средняя оценка ROC-AUC:  0.9985537087831677
# CPU times: total: 13min 55s
# Wall time: 7min 5s

# %%
# %%time
lr = LogisticRegression(random_state=RS,
                        penalty = None, 
                        solver = 'lbfgs', 
                        max_iter = 150)

pipeline3 = ImbPipeline([
    ('pca', pca),
    ('oversampler', ros),
    ('classifier', lr)
])

kf = KFold(n_splits=5, shuffle=True, random_state=RS)

scores_lr = cross_val_score(pipeline3, X_train, y_train, cv=kf, scoring='roc_auc')

print("ROC-AUC для каждого фолда: ", scores_lr)
print("Средняя оценка ROC-AUC: ", scores_lr.mean())
# Out:
# ROC-AUC для каждого фолда:  [0.96614594 0.96329607 0.99653596 0.98432766 0.99460303]
# Средняя оценка ROC-AUC:  0.9809817321142666
# CPU times: total: 12min 27s
# Wall time: 2min 13s

# %% [markdown]
#  #### По результатам кросс-валидации лучшей моделью оказалась `RandomForestClassifier` и `MLPClassifier`, которые показали минимальную разницу между значениями метрик по пяти фолдам на кросс-валидации. Также средняя оценка метрики `Accuracy` выше, чем у других моделей и составляет 92,72% и 92,47% соответственно.

# %% [markdown]
# ### Оценка моделей на тестовой выбрке

# %%
# Обучаем модель RandomForestClassifier и оцениваем на тесте
pipeline2.fit(X_train, y_train)

probabilities_valid1 = pipeline2.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, probabilities_valid1)
print("ROC-AUC:", roc_auc)
# Out:
# ROC-AUC: 0.9988646179221338

# %%
# Обучаем модель MLPClassifier и оцениваем на тесте
pipeline.fit(X_train, y_train)

probabilities_valid = pipeline.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, probabilities_valid)
print("ROC-AUC:", roc_auc)
# Out:
# ROC-AUC: 0.9739734925749939

# %%
# Обучаем модель GradientBoostingClassifier и оцениваем на тесте
pipeline1.fit(X_train, y_train)

probabilities_valid = pipeline1.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, probabilities_valid)
print("ROC-AUC:", roc_auc)
# Out:
# ROC-AUC: 0.9983788155897664

# %%
# Обучаем модель LogisticRegression и оцениваем на тесте
pipeline3.fit(X_train, y_train)

probabilities_valid = pipeline3.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, probabilities_valid)
print("ROC-AUC:", roc_auc)
# Out:
# ROC-AUC: 0.9858379081025304

# %% [markdown]
#  #### По результатам кросс-валидации и оценки на тесте лучшей моделью оказалась `RandomForestClassifier`, которая показала минимальную разницу между значениями метрики по пяти фолдам на кросс-валидации. Также средняя оценка метрики `ROC-AUC` выше, чем у других моделей и составляет на трейне 99,85% и на тесте 99,88%.

# %% [markdown]
# #### Тестирование лучшей модели

# %%
print("Classification Report RandomForestClassifier:")
print("Для тренировочной выборки:")
print(classification_report(y_train, pipeline2.predict(X_train)))
print ("Для тестовой выборки:")
print(classification_report(y_test, pipeline2.predict(X_test)))
# Out:
# Classification Report RandomForestClassifier:
# Для тренировочной выборки:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     76255
#            1       0.96      1.00      0.98       388
#
#     accuracy                           1.00     76643
#    macro avg       0.98      1.00      0.99     76643
# weighted avg       1.00      1.00      1.00     76643
#
# Для тестовой выборки:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     32681
#            1       0.99      1.00      0.99       166
#
#     accuracy                           1.00     32847
#    macro avg       0.99      1.00      1.00     32847
# weighted avg       1.00      1.00      1.00     32847

# %%
# Обучение модели на всём датасете
rf_full = pipeline2.fit(features, target)

# %%
 # Сохранение обученной модели в файл
with open('rf_full_model.pkl', 'wb') as file:
    pickle.dump(rf_full, file)

# %%
# Сохранение OneHotEncoder
with open('onehot_encoder.pkl', 'wb') as f:
    dill.dump(ohe, f)

# %%
# Сохранение StandardScaler
with open('scaler.pkl', 'wb') as f:
    dill.dump(std_scaler, f)
